# %% [markdown]
# # Atlanta airport delay analysis
#
# Modern Python reimplementation of a Cornell Six Sigma / DMAIC study of ATL delays.
#
# The batch entry point is `python scripts/run_pipeline.py`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_loader import load_flights
from src.cleaning import clean_flights
from src.analysis import group_means, delay_causes
from src.statistics import run_anova_suite

flights = clean_flights(load_flights())
print(len(flights), "operated ATL flights")
print(group_means(flights, "Reporting_Airline", "ArrDelay").head())
print(run_anova_suite(flights))
print(delay_causes(flights))
